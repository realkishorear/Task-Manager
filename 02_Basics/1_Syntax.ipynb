# %% [markdown]
# #### Ideas to discuss
# 1. Single line and multi line comments
# 2. Definition of Syntax and Semantics
# 3. Basic syntax rules in Python
# 4. Understanding semantics in Python
# 5. Common syntax errors and how to aviod them

# %% [markdown]
# - **Syntax** : Correct arrangement of words and letter in a code.
# - **Semantics** : Interpretation of meaning or interpretion of the code.

# %%
# Basic syntax 
# Note : Multiline comment doens't work in jupiter notebook

# 01. Python is case sensitive
name="Kishore"
Name="Kishore"
print(Name)
# Out:
# Kishore

# %%
# 02. Indentation
# Python uses indentation to define blocks of code. Used for grouping the statements.

age = 32
if age > 30 :
    print(age)
print(age)
# Out:
# 32
# 32

# %%
# 03. Line continuation
# Python can continue from next lines of code.
total = 10 + \
2
print(total)
# Out:
# 12

# %%
# 04. Multiple Statements on single line
# By seprating with semicolan you can use put multiple statements in same line
x = 10 ; y = 10 ; z = x + y
print(z)
# Out:
# 20

# %%
# Semantics
# Variable assignment
age = 32 
name = "Kishore"

# type inference : python is dynamically typed. It decides the data type on run time.

print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Name error
a = "Kishore"
b = 32
a = c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 a = "Kishore"
#       3 b = 32
# ----> 4 a = c
#
# NameError: name 'c' is not defined

# %%
# Code example of indentation
if True:
    print("This is a sample code block")
    if not False:
        print("This is another code block")
    else :
        print("Hey this is a sample block")
else :
    print("LOl")
# Out:
# This is a sample code block
# This is another code block
